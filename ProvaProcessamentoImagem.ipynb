# %% [markdown]
# <a href="https://colab.research.google.com/github/bot-leo/ProcessamentoDeImagem/blob/master/ProvaProcessamentoImagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL
import cv2

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-684f8bca-7d61-4f25-89fb-c2ad6d9b9a04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-684f8bca-7d61-4f25-89fb-c2ad6d9b9a04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving estrada.jpg to estrada.jpg

# %%
image = plt.imread("estrada.jpg")

# %%
plt.imshow(image)

# %%
image2 = cv2.imread("estrada.jpg")

# %%
image2[30:50, :] = (0, 0, 255)

# %%
image2[100:130, :] = (0, 200, 200)

# %%
image2[:, 200:220] = (255, 0, 127)

# %%
plt.imshow(image2)

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-0fc8623a-1754-4162-89b0-62b559647a00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fc8623a-1754-4162-89b0-62b559647a00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tigre.jpg to tigre.jpg

# %%
image3 = plt.imread("tigre.jpg")

# %%
plt.imshow(image3)

# %%
imageBlue = image3.copy()
imageBlue[:, :,[0,1]] = 0

plt.imshow(imageBlue)
